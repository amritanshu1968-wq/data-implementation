# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

# %%
#movie review Dataset
reviews = [
    "I love this movie",
    "this movie is fantastic",
    "I hate this movie",
    "this movie is boring"
]

# %%
vectorizer = TfidfVectorizer(stop_words='english')

# %%
X = vectorizer.fit_transform(reviews)

# %%
print(vectorizer.get_feature_names_out())
# Out:
# ['boring' 'fantastic' 'hate' 'love' 'movie']

# %%
tfidf_df = pd.DataFrame(
    X.toarray(),
      columns=vectorizer.get_feature_names_out()
      )

print(tfidf_df)
# Out:
#      boring  fantastic      hate      love     movie
# 0  0.000000   0.000000  0.000000  0.886548  0.462637
# 1  0.000000   0.886548  0.000000  0.000000  0.462637
# 2  0.000000   0.000000  0.886548  0.000000  0.462637
# 3  0.886548   0.000000  0.000000  0.000000  0.462637

# %%
new_review = ["I love fantastic movie"]

new_vector = vectorizer.transform(new_review)

new_df = pd.DataFrame(
    new_vector.toarray(),
    columns=vectorizer.get_feature_names_out()
    )
print(new_df)
# Out:
#    boring  fantastic  hate      love     movie
# 0     0.0   0.663385   0.0  0.663385  0.346182

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

reviews = [
    "Food was delicious",
    "Service was slow",
    "Delicious food and quick service",
    "Restaurant was clean"
]

vectorizer = TfidfVectorizer(stop_words='english')

X = vectorizer.fit_transform(reviews)

df = pd.DataFrame(
    X.toarray(),
    columns=vectorizer.get_feature_names_out()
)

print(df)
# Out:
#       clean  delicious      food     quick  restaurant   service      slow
# 0  0.000000   0.707107  0.707107  0.000000    0.000000  0.000000  0.000000
# 1  0.000000   0.000000  0.000000  0.000000    0.000000  0.619130  0.785288
# 2  0.000000   0.465809  0.465809  0.590819    0.000000  0.465809  0.000000
# 3  0.707107   0.000000  0.000000  0.000000    0.707107  0.000000  0.000000

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

documents = [
    "machine learning",
    "deep learning",
    "machine intelligence"
]

vectorizer = TfidfVectorizer(ngram_range=(1,2))

X = vectorizer.fit_transform(documents)

df = pd.DataFrame(
    X.toarray(),
    columns=vectorizer.get_feature_names_out()
)

print(df)
# Out:
#        deep  deep learning  intelligence  learning   machine  \
# 0  0.000000       0.000000      0.000000  0.517856  0.517856
# 1  0.622766       0.622766      0.000000  0.473630  0.000000
# 2  0.000000       0.000000      0.622766  0.000000  0.473630
#
#    machine intelligence  machine learning
# 0              0.000000          0.680919
# 1              0.000000          0.000000
# 2              0.622766          0.000000

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

documents = [
    "Python programming language",
    "Python coding language",
    "Football match today"
]

vectorizer = TfidfVectorizer()

X = vectorizer.fit_transform(documents)

similarity = cosine_similarity(X)

print(similarity)
# Out:
# [[1.         0.53634991 0.        ]
#  [0.53634991 1.         0.        ]
#  [0.         0.         1.        ]]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

documents = [
    "apple banana apple orange",
    "banana orange",
    "apple orange banana banana"
]

vectorizer = TfidfVectorizer(max_features=3)

X = vectorizer.fit_transform(documents)

df = pd.DataFrame(
    X.toarray(),
    columns=vectorizer.get_feature_names_out()
)

print(df)
# Out:
#       apple    banana    orange
# 0  0.876537  0.340355  0.340355
# 1  0.000000  0.707107  0.707107
# 2  0.499037  0.775093  0.387547

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

feedback = [
    "Teacher explains concepts clearly",
    "Teacher is very helpful",
    "Concepts are difficult",
    "Helpful teacher with good explanation"
]

vectorizer = TfidfVectorizer(stop_words='english')

X = vectorizer.fit_transform(feedback)

df = pd.DataFrame(
    X.toarray(),
    columns=vectorizer.get_feature_names_out()
)

print(df)
# Out:
#    clearly  concepts  difficult  explains  explanation     good   helpful  \
# 0  0.57458  0.453005   0.000000   0.57458      0.00000  0.00000  0.000000
# 1  0.00000  0.000000   0.000000   0.00000      0.00000  0.00000  0.777221
# 2  0.00000  0.619130   0.785288   0.00000      0.00000  0.00000  0.000000
# 3  0.00000  0.000000   0.000000   0.00000      0.57458  0.57458  0.453005
#
#     teacher
# 0  0.366747
# 1  0.629228
# 2  0.000000
# 3  0.366747

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

documents = [
    "Python is easy",
    "Python is powerful",
    "Machine learning with Python"
]

vectorizer = TfidfVectorizer()

X = vectorizer.fit_transform(documents)

new_doc = ["Python learning"]

new_vector = vectorizer.transform(new_doc)

df = pd.DataFrame(
    new_vector.toarray(),
    columns=vectorizer.get_feature_names_out()
)

print(df)
# Out:
#    easy   is  learning  machine  powerful    python  with
# 0   0.0  0.0  0.861037      0.0       0.0  0.508542   0.0

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

documents = [
    "This is a good book",
    "This book is very interesting",
    "Reading books is fun"
]

vectorizer = TfidfVectorizer(stop_words='english')

X = vectorizer.fit_transform(documents)

print(vectorizer.get_feature_names_out())
# Out:
# ['book' 'books' 'fun' 'good' 'interesting' 'reading']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

documents = [
    "Artificial Intelligence",
    "Machine Learning",
    "Artificial Intelligence and Machine Learning"
]

vectorizer = TfidfVectorizer(ngram_range=(1,2))

X = vectorizer.fit_transform(documents)

df = pd.DataFrame(
    X.toarray(),
    columns=vectorizer.get_feature_names_out()
)

print(df)
# Out:
#         and  and machine  artificial  artificial intelligence  intelligence  \
# 0  0.000000     0.000000    0.577350                 0.577350      0.577350
# 1  0.000000     0.000000    0.000000                 0.000000      0.000000
# 2  0.393129     0.393129    0.298984                 0.298984      0.298984
#
#    intelligence and  learning   machine  machine learning
# 0          0.000000  0.000000  0.000000          0.000000
# 1          0.000000  0.577350  0.577350          0.577350
# 2          0.393129  0.298984  0.298984          0.298984

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

documents = [
    "Artificial Intelligence",
    "Machine Learning",
    "Artificial Intelligence and Machine Learning"
]

vectorizer = TfidfVectorizer(ngram_range=(1,2))

X = vectorizer.fit_transform(documents)

df = pd.DataFrame(
    X.toarray(),
    columns=vectorizer.get_feature_names_out()
)

print(df)
# Out:
#         and  and machine  artificial  artificial intelligence  intelligence  \
# 0  0.000000     0.000000    0.577350                 0.577350      0.577350
# 1  0.000000     0.000000    0.000000                 0.000000      0.000000
# 2  0.393129     0.393129    0.298984                 0.298984      0.298984
#
#    intelligence and  learning   machine  machine learning
# 0          0.000000  0.000000  0.000000          0.000000
# 1          0.000000  0.577350  0.577350          0.577350
# 2          0.393129  0.298984  0.298984          0.298984

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

documents = [
    "Python programming",
    "Python coding",
    "Football match"
]

vectorizer = TfidfVectorizer()

X = vectorizer.fit_transform(documents)

similarity = cosine_similarity(X)

print(similarity)
# Out:
# [[1.         0.36644682 0.        ]
#  [0.36644682 1.         0.        ]
#  [0.         0.         1.        ]]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

documents = [
    "apple banana apple orange",
    "banana orange mango",
    "apple orange banana mango"
]

vectorizer = TfidfVectorizer(max_features=5)

X = vectorizer.fit_transform(documents)

df = pd.DataFrame(
    X.toarray(),
    columns=vectorizer.get_feature_names_out()
)

print(df)
# Out:
#       apple    banana     mango    orange
# 0  0.876537  0.340355  0.000000  0.340355
# 1  0.000000  0.522842  0.673255  0.522842
# 2  0.558478  0.433708  0.558478  0.433708

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

emails = [
    "Meeting at 10 AM",
    "Project meeting tomorrow",
    "Lunch at cafeteria"
]

vectorizer = TfidfVectorizer()

X = vectorizer.fit_transform(emails)

print(vectorizer.get_feature_names_out())
print(X.toarray())
# Out:
# ['10' 'am' 'at' 'cafeteria' 'lunch' 'meeting' 'project' 'tomorrow']
# [[0.5628291  0.5628291  0.42804604 0.         0.         0.42804604
#   0.         0.        ]
#  [0.         0.         0.         0.         0.         0.4736296
#   0.62276601 0.62276601]
#  [0.         0.         0.4736296  0.62276601 0.62276601 0.
#   0.         0.        ]]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

documents = [
    "cat dog mouse",
    "cat dog",
    "cat bird"
]

vectorizer = TfidfVectorizer(max_df=0.8)

X = vectorizer.fit_transform(documents)

print(vectorizer.get_feature_names_out())
print(X.toarray())
# Out:
# ['bird' 'dog' 'mouse']
# [[0.         0.60534851 0.79596054]
#  [0.         1.         0.        ]
#  [1.         0.         0.        ]]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

documents = [
    "AI ML Python",
    "Python Data Science",
    "AI Python"
]

vectorizer = TfidfVectorizer(min_df=2)

X = vectorizer.fit_transform(documents)

print(vectorizer.get_feature_names_out())
print(X.toarray())
# Out:
# ['ai' 'python']
# [[0.78980693 0.61335554]
#  [0.         1.        ]
#  [0.78980693 0.61335554]]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

documents = [
    "AI ML Python",
    "AI Data",
    "Python ML"
]

vectorizer = TfidfVectorizer(token_pattern=r"(?u)\b\w+\b")

X = vectorizer.fit_transform(documents)

print(vectorizer.get_feature_names_out())
# Out:
# ['ai' 'data' 'ml' 'python']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

documents = [
    "Artificial Intelligence",
    "Machine Learning",
    "Deep Learning"
]

vectorizer = TfidfVectorizer()

X = vectorizer.fit_transform(documents)

print("Shape:", X.shape)
# Out:
# Shape: (3, 5)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

documents = [
    "apple banana",
    "banana orange",
    "apple orange"
]

vectorizer = TfidfVectorizer()

vectorizer.fit(documents)

print(vectorizer.vocabulary_)
# Out:
# {'apple': 0, 'banana': 1, 'orange': 2}

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

documents = [
    "AI ML",
    "Python AI",
    "ML Python"
]

vectorizer = TfidfVectorizer(token_pattern=r"(?u)\b\w+\b")

vectorizer.fit(documents)

print(vectorizer.get_feature_names_out())
# Out:
# ['ai' 'ml' 'python']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

documents = [
    "Python",
    "python",
    "PYTHON"
]

vectorizer = TfidfVectorizer(lowercase=False)

X = vectorizer.fit_transform(documents)

print(vectorizer.get_feature_names_out())
# Out:
# ['PYTHON' 'Python' 'python']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

def calculate_tfidf(documents):
    vectorizer = TfidfVectorizer()
    matrix = vectorizer.fit_transform(documents)
    
    return vectorizer, matrix


documents = [
    "Python is easy",
    "Python is powerful",
    "Machine learning is powerful"
]

vectorizer, matrix = calculate_tfidf(documents)

print(matrix.toarray())
# Out:
# [[0.72033345 0.42544054 0.         0.         0.         0.54783215]
#  [0.         0.48133417 0.         0.         0.61980538 0.61980538]
#  [0.         0.34520502 0.5844829  0.5844829  0.44451431 0.        ]]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

documents = [
    "Python programming is easy",
    "Machine learning uses Python",
    "Football is a popular sport",
    "Python is used for data science"
]

vectorizer = TfidfVectorizer()

X = vectorizer.fit_transform(documents)

query = ["Python data science"]

query_vector = vectorizer.transform(query)

similarity = cosine_similarity(query_vector, X)[0]

for i, score in enumerate(similarity):
    print("Document", i + 1, ":", score)
# Out:
# Document 1 : 0.1565062303428976
# Document 2 : 0.14224754516347735
# Document 3 : 0.0
# Document 4 : 0.7071067811865476

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

documents = [
    "Python programming is easy",
    "Machine learning uses Python",
    "Football is a popular sport",
    "Python is used for data science"
]

vectorizer = TfidfVectorizer()

X = vectorizer.fit_transform(documents)

query = ["Python data science"]

query_vector = vectorizer.transform(query)

similarity = cosine_similarity(query_vector, X)[0]

index = similarity.argmax()

print("Most Similar Document:")
print(documents[index])

print("Similarity Score:", similarity[index])
# Out:
# Most Similar Document:
# Python is used for data science
# Similarity Score: 0.7071067811865476

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

documents = [
    "Python is used in data science",
    "Java is used for backend development",
    "Machine learning uses Python",
    "HTML CSS and JavaScript are frontend technologies"
]

vectorizer = TfidfVectorizer()

X = vectorizer.fit_transform(documents)

query = input("Enter your search query: ")

query_vector = vectorizer.transform([query])

scores = cosine_similarity(query_vector, X)[0]

ranked_documents = scores.argsort()[::-1]

for index in ranked_documents:
    print("\nScore:", scores[index])
    print(documents[index])
# Out:
# Score: 0.0
# HTML CSS and JavaScript are frontend technologies
#
# Score: 0.0
# Machine learning uses Python
#
# Score: 0.0
# Java is used for backend development
#
# Score: 0.0
# Python is used in data science

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

reviews = [
    "This movie was excellent",
    "Amazing movie",
    "I loved this film",
    "Very good movie",
    "Worst movie ever",
    "Very boring film",
    "I hated this movie",
    "Terrible experience"
]

labels = [
    1, 1, 1, 1,
    0, 0, 0, 0
]

vectorizer = TfidfVectorizer()

X = vectorizer.fit_transform(reviews)

model = LogisticRegression()

model.fit(X, labels)

new_review = ["This movie was amazing"]

new_vector = vectorizer.transform(new_review)

prediction = model.predict(new_vector)

if prediction[0] == 1:
    print("Positive Review")
else:
    print("Negative Review")
# Out:
# Positive Review

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

documents = [
    "excellent movie",
    "amazing film",
    "very good movie",
    "I loved it",
    "terrible movie",
    "very bad film",
    "worst movie",
    "I hated it"
]

labels = [1, 1, 1, 1, 0, 0, 0, 0]

X_train, X_test, y_train, y_test = train_test_split(
    documents,
    labels,
    test_size=0.25,
    random_state=42
)

vectorizer = TfidfVectorizer()

X_train_tfidf = vectorizer.fit_transform(X_train)

X_test_tfidf = vectorizer.transform(X_test)

model = LogisticRegression()

model.fit(X_train_tfidf, y_train)

predictions = model.predict(X_test_tfidf)

accuracy = accuracy_score(y_test, predictions)

print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.5

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

def calculate_tfidf(documents):
    vectorizer = TfidfVectorizer()
    matrix = vectorizer.fit_transform(documents)
    
    return vectorizer, matrix


documents = [
    "Python is easy",
    "Python is powerful",
    "Machine learning is powerful"
]

vectorizer, matrix = calculate_tfidf(documents)

print(matrix.toarray())
# Out:
# [[0.72033345 0.42544054 0.         0.         0.         0.54783215]
#  [0.         0.48133417 0.         0.         0.61980538 0.61980538]
#  [0.         0.34520502 0.5844829  0.5844829  0.44451431 0.        ]]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

documents = [
    "Python programming is easy",
    "Machine learning uses Python",
    "Football is a popular sport",
    "Python is used for data science"
]

vectorizer = TfidfVectorizer()

X = vectorizer.fit_transform(documents)

query = ["Python data science"]

query_vector = vectorizer.transform(query)

similarity = cosine_similarity(query_vector, X)[0]

for i, score in enumerate(similarity):
    print("Document", i + 1, ":", score)
# Out:
# Document 1 : 0.1565062303428976
# Document 2 : 0.14224754516347735
# Document 3 : 0.0
# Document 4 : 0.7071067811865476

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

documents = [
    "Python is widely used for data science",
    "Machine learning is a branch of artificial intelligence",
    "Python is popular for machine learning",
    "Java is widely used for backend development",
    "React is used for frontend development",
    "Data science uses Python pandas numpy and machine learning"
]

vectorizer = TfidfVectorizer(stop_words='english')

X = vectorizer.fit_transform(documents)

query = input("Search: ")

query_vector = vectorizer.transform([query])

similarity = cosine_similarity(query_vector, X)[0]

ranking = similarity.argsort()[::-1]

print("\nSearch Results:\n")

for i in ranking[:3]:

    print("Similarity:", round(similarity[i], 3))
    print("Document:", documents[i])
    print()
# Out:
# Search Results:
#
# Similarity: 0.0
# Document: Data science uses Python pandas numpy and machine learning
#
# Similarity: 0.0
# Document: React is used for frontend development
#
# Similarity: 0.0
# Document: Java is widely used for backend development

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

documents = [
    "Python programming",
    "Machine learning",
    "Data science"
]

vectorizer = TfidfVectorizer()

X = vectorizer.fit_transform(documents)

print("Number of documents:", X.shape[0])
print("Number of features:", X.shape[1])
# Out:
# Number of documents: 3
# Number of features: 6

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

documents = [
    "python programming",
    "python machine learning",
    "machine learning"
]

vectorizer = TfidfVectorizer()

X = vectorizer.fit_transform(documents)

print(X)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 7 stored elements and shape (3, 4)>
#   Coords	Values
#   (0, 3)	0.6053485081062916
#   (0, 2)	0.7959605415681652
#   (1, 3)	0.5773502691896257
#   (1, 1)	0.5773502691896257
#   (1, 0)	0.5773502691896257
#   (2, 1)	0.7071067811865476
#   (2, 0)	0.7071067811865476

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

documents = [
    "python programming",
    "python machine learning"
]

vectorizer = TfidfVectorizer()

X = vectorizer.fit_transform(documents)

print("Sparse Matrix:")
print(X)

print("\nDense Matrix:")
print(X.toarray())
# Out:
# Sparse Matrix:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 5 stored elements and shape (2, 4)>
#   Coords	Values
#   (0, 3)	0.5797386715376657
#   (0, 2)	0.8148024746671689
#   (1, 3)	0.4494364165239821
#   (1, 1)	0.6316672017376245
#   (1, 0)	0.6316672017376245
#
# Dense Matrix:
# [[0.         0.         0.81480247 0.57973867]
#  [0.6316672  0.6316672  0.         0.44943642]]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

documents = [
    "python python python",
    "python machine learning",
    "machine learning"
]

vectorizer = TfidfVectorizer(sublinear_tf=True)

X = vectorizer.fit_transform(documents)

print(X.toarray())
# Out:
# [[0.         0.         1.        ]
#  [0.57735027 0.57735027 0.57735027]
#  [0.70710678 0.70710678 0.        ]]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

documents = [
    "python machine learning",
    "python data science",
    "machine learning python"
]

vectorizer = TfidfVectorizer(smooth_idf=False)

X = vectorizer.fit_transform(documents)

print(X.toarray())
# Out:
# [[0.         0.6316672  0.6316672  0.44943642 0.        ]
#  [0.67009179 0.         0.         0.31930233 0.67009179]
#  [0.         0.6316672  0.6316672  0.44943642 0.        ]]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

documents = [
    "python machine learning",
    "python data science",
    "machine learning python"
]

vectorizer = TfidfVectorizer(smooth_idf=False)

X = vectorizer.fit_transform(documents)

print(X.toarray())
# Out:
# [[0.         0.6316672  0.6316672  0.44943642 0.        ]
#  [0.67009179 0.         0.         0.31930233 0.67009179]
#  [0.         0.6316672  0.6316672  0.44943642 0.        ]]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

documents = [
    "machine learning",
    "deep learning",
    "machine intelligence"
]

vectorizer = TfidfVectorizer(ngram_range=(2, 2))

X = vectorizer.fit_transform(documents)

print(vectorizer.get_feature_names_out())
# Out:
# ['deep learning' 'machine intelligence' 'machine learning']

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

texts = [
    "excellent movie",
    "amazing film",
    "great movie",
    "good acting",
    "terrible movie",
    "bad film",
    "worst acting",
    "boring movie"
]

labels = [1, 1, 1, 1, 0, 0, 0, 0]

X_train, X_test, y_train, y_test = train_test_split(
    texts,
    labels,
    test_size=0.25,
    random_state=42
)

vectorizer = TfidfVectorizer()

X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

print("Training shape:", X_train_tfidf.shape)
print("Testing shape:", X_test_tfidf.shape)
# Out:
# Training shape: (6, 8)
# Testing shape: (2, 8)

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

texts = [
    "excellent movie",
    "amazing film",
    "great movie",
    "good acting",
    "terrible movie",
    "bad film",
    "worst acting",
    "boring movie"
]

labels = [1, 1, 1, 1, 0, 0, 0, 0]

X_train, X_test, y_train, y_test = train_test_split(
    texts,
    labels,
    test_size=0.25,
    random_state=42
)

vectorizer = TfidfVectorizer()

X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

print("Training shape:", X_train_tfidf.shape)
print("Testing shape:", X_test_tfidf.shape)
# Out:
# Training shape: (6, 8)
# Testing shape: (2, 8)

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

texts = [
    "excellent movie",
    "amazing film",
    "great movie",
    "good acting",
    "terrible movie",
    "bad film",
    "worst acting",
    "boring movie"
]

labels = [1, 1, 1, 1, 0, 0, 0, 0]

X_train, X_test, y_train, y_test = train_test_split(
    texts,
    labels,
    test_size=0.25,
    random_state=42
)

vectorizer = TfidfVectorizer()

X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

model = LogisticRegression()

model.fit(X_train_tfidf, y_train)

predictions = model.predict(X_test_tfidf)

accuracy = accuracy_score(y_test, predictions)

print("Predictions:", predictions)
print("Actual:", y_test)
print("Accuracy:", accuracy)
# Out:
# Predictions: [0 0]
# Actual: [1, 0]
# Accuracy: 0.5

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

precision = precision_score(y_test, predictions)
recall = recall_score(y_test, predictions)
f1 = f1_score(y_test, predictions)

print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
# c:\Users\Amritanshu\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, predictions)

print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[1 0]
#  [1 0]]

# %%
from sklearn.metrics import classification_report

print("Classification Report:")
print(classification_report(y_test, predictions))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         1
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2
# c:\Users\Amritanshu\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\Amritanshu\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\Amritanshu\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score
)

accuracy = accuracy_score(y_test, predictions)
precision = precision_score(y_test, predictions)
recall = recall_score(y_test, predictions)
f1 = f1_score(y_test, predictions)

print("Accuracy :", accuracy)
print("Precision:", precision)
print("Recall   :", recall)
print("F1 Score :", f1)
# Out:
# Accuracy : 0.5
# Precision: 0.0
# Recall   : 0.0
# F1 Score : 0.0
# c:\Users\Amritanshu\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

ConfusionMatrixDisplay.from_predictions(
    y_test,
    predictions
)

plt.title("Confusion Matrix")
plt.show()
